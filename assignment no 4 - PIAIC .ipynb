# %%
n = int(input("enter number "))
sum = 0
for a in range(0,n+1):
    sum += a
print(sum)
# Out:
# enter number 44
# 990

# %%
inp_sub = input("Please enter a subject : ").title() 

student_123456 = {
    "Name":"Rohan",
    "Class":"VI",
    "Percentage":"80%",
    "Marks":{
        "Quiz1":40,
        "Quiz2":45,
        "Mid":50,
        "Final":55
    }
}

if inp_sub in student_123456["Marks"]:
    print(student_123456["Marks"][inp_sub])
else:
    print("uncorrect subject entered")
# Out:
# Please enter a subject : quiz1
# 40

# %%
class_1A = {"name":"AI",
           "marks":
           {
            "Quiz1":50,
            "Quiz2":60,
            "mid":61,
            "final":62
           }
}

class_1B = {"name":"CNC",
           "marks":
           {
            "Quiz1":55,
            "Quiz2":64,
            "mid":49,
            "final":39
           }
}

class_2A = {"name":"AI",
           "marks":
           {"Quiz1":33,
            "Quiz2":90,
            "Mid":77,
            "final":60
           }
}
class_2B = {"name":"CNC",
           "marks":
           {"Quiz":58,
            "Quiz2":87,
            "Mid":54,
            "final":87
           }
}
class_3A = {"name":"AI",
           "marks":
           {"Quiz1":56,
            "Quiz2":67,
            "Mid":77,
            "final":76
           }
}
class_3B = {"name":"CNC",
            "marks":
            {"Quiz1":49,
             "Quiz2":58,
             "Mid":77,
             "final":77
            }
}
class_4A = {"name":"AI",
            "marks":{
                "Quiz1":55,
                "Quiz2":53,
                "Mid":76,
                "final":89
            }
           }
class_4B = {"name":"CNC",
            "marks":{
                "Quiz1":77,
                "Quiz2":97,
                "Mid":99,
                "final":52
            }
    
}
class_5A = {"name":"AI",
            "marks":{
                "Quiz1":66,
                "Quiz2":88,
                "mid":42,
                "final":50
            }
    
}
class_5B = {"name":"CNC",
            "marks":{
                "Quiz1":68,
                "Quiz2":82,
                "mid":86,
                "final":50
            }
    
}
class_6A = {"name":"AI",
            "marks":{
                "Quiz1":93,
                "Quiz2":92,
                "mid":91,
                "final":89
            }
    
}
class_6B = {"name":"CNC",
            "marks":{
                "Quiz1":49,
                "Quiz2":69,
                "mid":86,
                "final":50
            }
    
}
class_7A = {"name":"AI",
            "marks":{
                "Quiz1":54,
                "Quiz2":84,
                "mid":74,
                "final":50
            }
    
}
class_7B = {"name":"CNC",
            "marks":{
                "Quiz1":66,
                "Quiz2":88,
                "mid":31,
                "final":49
            }
    
}
class_8A = {"name":"AI",
            "marks":{
                "Quiz1":66,
                "Quiz2":76,
                "mid":79,
                "final":50
            }
    
}
class_8B = {"name":"CNC",
            "marks":{
                "Quiz1":50,
                "Quiz2":60,
                "mid":70,
                "final":80
            }
    
}
class_9A = {"name":"AI",
            "marks":{
                "Quiz1":21,
                "Quiz2":22,
                "mid":23,
                "final":24
            }
    
}
class_9B = {"name":"CNC",
            "marks":{
                "Quiz1":25,
                "Quiz2":26,
                "mid":27,
                "final":28
            }
    
}
class_10A = {"name":"AI",
            "marks":{
                "Quiz1":29,
                "Quiz2":30,
                "mid":31,
                "final":32
            }
    
}
class_10B = {"name":"AI",
            "marks":{
                "Quiz1":33,
                "Quiz2":34,
                "mid":35,
                "final":36
            }
    
}



student_001 = {"name":"rohan",
               "class_AI":class_1A,
               "class_CNC":class_1B,
}

student_002 = {"name":"kamran",
               "class_AI":class_2A,
               "class_CNC":class_2B
}

student_003 = {"name":"arshad",
               "class_AI":class_3A,
               "class_CNC":class_3B
}
student_004 = {"name":"husnain",
               "class_AI":class_4A,
               "class_CNC":class_4B
}
student_005 = {"name":"iqbal",
               "class_AI":class_5A,
               "class_CNC":class_5B
}
student_006 = {"name":"junaid",
               "class_AI":class_6A,
               "class_CNC":class_6B
}
student_007 = {"name":"mohsin",
               "class_AI":class_7A,
               "class_CNC":class_7B
}
student_008 = {"name":"farhan",
               "class_AI":class_8A,
               "class_CNC":class_8B
}
student_009 = {"name":"ehsan",
               "class_AI":class_9A,
               "class_CNC":class_9B
}
student_010 = {"name":"tariq",
               "class_AI":class_10A,
               "class_CNC":class_10B
}
students_roll_no = [student_001,student_002,student_003,student_004,student_005,student_006,
                    student_007,student_008,student_009,student_010]

# %%
inp_3 = input("Please enter a name: ")
for a in students_roll_no:
    if inp_3 == a["name"]:
        print("class_AI",a["class_AI"]["marks"])
        print("class_CNC",a["class_CNC"]["marks"])
# Out:
# Please enter a name: mohsin
# class_AI {'Quiz1': 54, 'Quiz2': 84, 'mid': 74, 'final': 50}
# class_CNC {'Quiz1': 66, 'Quiz2': 88, 'mid': 31, 'final': 49}

# %%
customer_29876 = {"discount":
                  ["brother_in_law","loyalty","volume"]
                 }
discount_amout = 0
if "brother_in_law" in customer_29876["discount"]:
    discount_amout += .30
if "loyalty" in customer_29876["discount"]:
    discount_amout += .15
if "volume" in customer_29876["discount"]:
    discount_amout += .10
if "standard" in customer_29876["discount"]:
    discount_amout += .05

    
print(customer_29876["discount"])    
print("Discount applied to the customer_29876 is:",round(discount_amout,2))
# Out:
# ['brother_in_law', 'loyalty', 'volume']
# Discount applied to the customer_29876 is: 0.55
